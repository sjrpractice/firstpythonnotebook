# %% [markdown]
# # First Python Notebook
# By [Steve Reilly](https://www.stevereilly.com)

# %%
import pandas as pd

# %%
accident_list = pd.read_csv("https://raw.githubusercontent.com/palewire/first-python-notebook/main/docs/src/_static/ntsb-accidents.csv")

# %%
accident_list.head(10)
# Out:
#          event_id   ntsb_make ntsb_model ntsb_number  year  \
# 0  20061222X01838        BELL        407  NYC07FA048  2006
# 1  20060817X01187    ROBINSON   R22 BETA  LAX06LA257  2006
# 2  20060111X00044    ROBINSON        R44  MIA06FA039  2006
# 3  20060419X00461    ROBINSON     R44 II  DFW06FA102  2006
# 4  20060208X00181    ROBINSON        R44  SEA06LA052  2006
# 5  20060228X00255    ROBINSON        R22  ANC06FA020  2006
# 6  20060824X01237  EUROCOPTER  AS-350-B3  SEA06GA158  2006
# 7  20060916X01352      HUGHES       369D  LAX06LA288  2006
# 8  20061122X01705      HUGHES       369E  SEA07LA021  2006
# 9  20060306X00268   SCHWEIZER     269C-1  LAX06LA123  2006
#
#                   date            city state country  total_fatalities  \
# 0  12/14/2006 00:00:00        DAGSBORO    DE     USA                 2
# 1  08/10/2006 00:00:00          TUCSON    AZ     USA                 1
# 2  01/01/2006 00:00:00     GRAND RIDGE    FL     USA                 3
# ...

# %%
accident_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                163 non-null    object
#  1   ntsb_make               163 non-null    object
#  2   ntsb_model              163 non-null    object
#  3   ntsb_number             163 non-null    object
#  4   year                    163 non-null    int64
#  5   date                    163 non-null    object
#  6   city                    163 non-null    object
#  7   state                   162 non-null    object
#  8   country                 163 non-null    object
#  9   total_fatalities        163 non-null    int64
#  10  latimes_make            163 non-null    object
#  11  latimes_model           163 non-null    object
#  12  latimes_make_and_model  163 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 16.7+ KB

# %%
accident_list["latimes_make_and_model"].value_counts()
# Out:
# latimes_make_and_model
# ROBINSON R44             38
# AIRBUS 350               29
# BELL 206                 28
# ROBINSON R22             20
# BELL 407                 13
# HUGHES 369               13
# MCDONNELL DOUGLAS 369     6
# SCHWEIZER 269             5
# AIRBUS 135                4
# bell 206                  2
# SIKORSKY 76               2
# AGUSTA 109                2
# AIRBUS 130                1
# Name: count, dtype: int64

# %%
accident_list["latimes_make_and_model"] = accident_list["latimes_make_and_model"].str.upper()

# %%
sum(accident_list["total_fatalities"])
# Out:
# 336

# %%
accident_list["ntsb_make"].value_counts()
# Out:
# ntsb_make
# BELL                              37
# ROBINSON                          25
# EUROCOPTER                        18
# ROBINSON HELICOPTER               18
# ROBINSON HELICOPTER COMPANY       15
# HUGHES                            13
# SCHWEIZER                          5
# AEROSPATIALE                       5
# BELL HELICOPTER TEXTRON            4
# AIRBUS HELICOPTERS                 2
# MCDONNELL DOUGLAS HELICOPTER       2
# AGUSTA SPA                         2
# SIKORSKY                           2
# MCDONNELL DOUGLAS HELI CO          2
# EUROCOPTER DEUTSCHLAND GMBH        2
# EUROCOPTER FRANCE                  2
# AMERICAN EUROCOPTER LLC            1
# MD HELICOPTERS INC                 1
# BELL HELICOPTER                    1
# MCDONNELL DOUGLAS                  1
# AMERICAN EUROCOPTER CORP           1
# AIRBUS HELICOPTERS INC             1
# AIRBUS HELICOPTERS (EUROCOPTE      1
# BELL HELICOPTER TEXTRON CANADA     1
# AIRBUS                             1
# ...

# %%
accident_list["year"].value_counts()
# Out:
# year
# 2008    22
# 2006    20
# 2010    18
# 2013    18
# 2014    17
# 2007    16
# 2012    16
# 2009    15
# 2015    11
# 2016    10
# Name: count, dtype: int64

# %%
accident_list["state"].value_counts()
# Out:
# state
# CA    16
# TX    15
# AZ    14
# FL     9
# WA     8
# LA     8
# TN     6
# AK     6
# AL     5
# UT     5
# OK     5
# MT     4
# HI     4
# MO     4
# OR     4
# GM     3
# WI     3
# KY     3
# PA     3
# NM     3
# CO     3
# IA     3
# IN     2
# NV     2
# NC     2
# MD     2
# AR     2
# VA     2
# MS     2
# NY     2
# MA     1
# WV     1
# WY     1
# DE     1
# GA     1
# KS     1
# NJ     1
# SC     1
# MI     1
# DC     1
# ID     1
# PR     1
# Name: count, dtype: int64

# %%
(accident_list["ntsb_make"].value_counts())
# Out:
# ntsb_make
# BELL                              37
# ROBINSON                          25
# EUROCOPTER                        18
# ROBINSON HELICOPTER               18
# ROBINSON HELICOPTER COMPANY       15
# HUGHES                            13
# SCHWEIZER                          5
# AEROSPATIALE                       5
# BELL HELICOPTER TEXTRON            4
# AIRBUS HELICOPTERS                 2
# MCDONNELL DOUGLAS HELICOPTER       2
# AGUSTA SPA                         2
# SIKORSKY                           2
# MCDONNELL DOUGLAS HELI CO          2
# EUROCOPTER DEUTSCHLAND GMBH        2
# EUROCOPTER FRANCE                  2
# AMERICAN EUROCOPTER LLC            1
# MD HELICOPTERS INC                 1
# BELL HELICOPTER                    1
# MCDONNELL DOUGLAS                  1
# AMERICAN EUROCOPTER CORP           1
# AIRBUS HELICOPTERS INC             1
# AIRBUS HELICOPTERS (EUROCOPTE      1
# BELL HELICOPTER TEXTRON CANADA     1
# AIRBUS                             1
# ...

# %%
my_state = "MO"

# %%
accident_list["state"]
# Out:
# 0      DE
# 1      AZ
# 2      FL
# 3      TX
# 4      MT
#        ..
# 158    KY
# 159    LA
# 160    TN
# 161    AK
# 162    AR
# Name: state, Length: 163, dtype: object

# %%
accident_list["state"] == my_state
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 158    False
# 159    False
# 160    False
# 161    False
# 162    False
# Name: state, Length: 163, dtype: bool

# %%
accident_list[accident_list["state"] == my_state]
# Out:
#            event_id                      ntsb_make ntsb_model ntsb_number  \
# 55   20080908X01405                       ROBINSON     R44 II  DFW08FA218
# 73   20101015X73141                           BELL       206B  CEN11GA020
# 110  20130525X61706    ROBINSON HELICOPTER COMPANY     R44 II  CEN13FA295
# 144  20150308X10201  AIRBUS HELICOPTERS (EUROCOPTE  EC-130-B4  CEN15FA164
#
#      year                 date             city state country  \
# 55   2008  08/29/2008 00:00:00        RIDGEDALE    MO     USA
# 73   2010  10/15/2010 00:00:00  CLARKSON VALLEY    MO     USA
# 110  2013  05/24/2013 00:00:00    CROSS TIMBERS    MO     USA
# 144  2015  03/06/2015 00:00:00         ST LOUIS    MO     USA
#
#      total_fatalities latimes_make latimes_model latimes_make_and_model
# 55                  2     ROBINSON           R44           ROBINSON R44
# 73                  1         BELL           206               BELL 206
# ...

# %%
accident_list[accident_list["total_fatalities"] >1]
# Out:
#            event_id           ntsb_make ntsb_model ntsb_number  year  \
# 0    20061222X01838                BELL        407  NYC07FA048  2006
# 2    20060111X00044            ROBINSON        R44  MIA06FA039  2006
# 3    20060419X00461            ROBINSON     R44 II  DFW06FA102  2006
# 5    20060228X00255            ROBINSON        R22  ANC06FA020  2006
# 6    20060824X01237          EUROCOPTER  AS-350-B3  SEA06GA158  2006
# ..              ...                 ...        ...         ...   ...
# 150  20151216X13718  AIRBUS HELICOPTERS      AS350  WPR16FA040  2015
# 152  20151118X05037  AIRBUS HELICOPTERS   AS350B3E  WPR16FA029  2015
# 153  20161116X00108              HUGHES  369D/500D  WPR17FA021  2016
# 154  20160326X80544          EUROCOPTER  AS 350 B2  ERA16FA140  2016
# 160  20160404X74644                BELL        206  ERA16FA144  2016
#
#                     date            city state country  total_fatalities  \
# ...

# %%
accident_list.groupby("latimes_make_and_model").size()
# Out:
# latimes_make_and_model
# AGUSTA 109                2
# AIRBUS 130                1
# AIRBUS 135                4
# AIRBUS 350               29
# BELL 206                 30
# BELL 407                 13
# HUGHES 369               13
# MCDONNELL DOUGLAS 369     6
# ROBINSON R22             20
# ROBINSON R44             38
# SCHWEIZER 269             5
# SIKORSKY 76               2
# dtype: int64

# %%
accident_list.groupby("latimes_make_and_model")["total_fatalities"].sum()
# Out:
# latimes_make_and_model
# AGUSTA 109                5
# AIRBUS 130                1
# AIRBUS 135               11
# AIRBUS 350               81
# BELL 206                 61
# BELL 407                 35
# HUGHES 369               19
# MCDONNELL DOUGLAS 369     7
# ROBINSON R22             27
# ROBINSON R44             71
# SCHWEIZER 269             7
# SIKORSKY 76              11
# Name: total_fatalities, dtype: int64

# %%
accident_counts = accident_list.groupby("latimes_make_and_model").size().rename("accidents").reset_index()

# %%
accident_counts
# Out:
#    latimes_make_and_model  accidents
# 0              AGUSTA 109          2
# 1              AIRBUS 130          1
# 2              AIRBUS 135          4
# 3              AIRBUS 350         29
# 4                BELL 206         30
# 5                BELL 407         13
# 6              HUGHES 369         13
# 7   MCDONNELL DOUGLAS 369          6
# 8            ROBINSON R22         20
# 9            ROBINSON R44         38
# 10          SCHWEIZER 269          5
# 11            SIKORSKY 76          2

# %%
survey = pd.read_csv("https://raw.githubusercontent.com/palewire/first-python-notebook/main/docs/src/_static/faa-survey.csv")

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   latimes_make_and_model  12 non-null     object
#  1   total_hours             12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
accident_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   latimes_make_and_model  12 non-null     object
#  1   accidents               12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
survey['latimes_make_and_model'] = survey['latimes_make_and_model'].str.upper()

# %%
pd.merge(accident_counts, survey, on="latimes_make_and_model")
# Out:
#    latimes_make_and_model  accidents  total_hours
# 0              AGUSTA 109          2       362172
# 1              AIRBUS 130          1      1053786
# 2              AIRBUS 135          4       884596
# 3              AIRBUS 350         29      3883490
# 4                BELL 206         30      5501308
# 5                BELL 407         13      2113788
# 6              HUGHES 369         13      1201688
# 7   MCDONNELL DOUGLAS 369          6       550689
# 8            ROBINSON R22         20      2970806
# 9            ROBINSON R44         38      2359729
# 10          SCHWEIZER 269          5      1139326
# 11            SIKORSKY 76          2       915515

# %%
merged_list = pd.merge(accident_counts, survey, on="latimes_make_and_model")

# %%
accident_list.groupby("state")["total_fatalities"].sum()
# Out:
# state
# AK    11
# AL    11
# AR     4
# AZ    44
# CA    32
# CO     5
# DC     1
# DE     2
# FL    18
# GA     2
# GM     4
# HI     8
# IA     5
# ID     4
# IN     5
# KS     1
# KY     5
# LA    19
# MA     1
# MD     7
# MI     2
# MO     6
# MS     3
# MT     4
# NC     2
# NJ     9
# NM     8
# NV     2
# NY     3
# OK     8
# OR     8
# PA     4
# PR     1
# SC     3
# TN    16
# TX    35
# UT     9
# VA     3
# WA    12
# WI     6
# WV     1
# WY     1
# Name: total_fatalities, dtype: int64

# %%
accident_list[accident_list["state"] == "TX"]
# Out:
#            event_id                    ntsb_make   ntsb_model ntsb_number  \
# 3    20060419X00461                     ROBINSON       R44 II  DFW06FA102
# 26   20070530X00664                   EUROCOPTER    AS 350 B3  DFW07GA119
# 41   20081211X45825                         BELL       206L-4  CEN09FA086
# 47   20080505X00592                     ROBINSON          R44  DFW08LA122
# 49   20081013X24743                         BELL          206  CEN09FA012
# 52   20080222X00227            EUROCOPTER FRANCE      AS350B2  DFW08FA062
# 54   20080613X00858                         BELL          407  DEN08FA101
# 84   20100306X05331          ROBINSON HELICOPTER  R22 BETA II  CEN10FA139
# 86   20100206X10511                 AEROSPATIALE        AS350  CEN10FA113
# 93   20121012X13500  ROBINSON HELICOPTER COMPANY       R44 II  CEN13FA010
# 94   20120910X05133          ROBINSON HELICOPTER     R22 BETA  CEN12FA621
# 102  20121128X12341                       HUGHES          369  CEN13FA075
# ...

# %%
merged_list.sort_values('total_hours')
# Out:
#    latimes_make_and_model  accidents  total_hours
# 0              AGUSTA 109          2       362172
# 7   MCDONNELL DOUGLAS 369          6       550689
# 2              AIRBUS 135          4       884596
# 11            SIKORSKY 76          2       915515
# 1              AIRBUS 130          1      1053786
# 10          SCHWEIZER 269          5      1139326
# 6              HUGHES 369         13      1201688
# 5                BELL 407         13      2113788
# 9            ROBINSON R44         38      2359729
# 8            ROBINSON R22         20      2970806
# 3              AIRBUS 350         29      3883490
# 4                BELL 206         30      5501308

# %%
accident_list[accident_list["ntsb_number"] == "ERA13LA057"]
# Out:
#            event_id ntsb_make ntsb_model ntsb_number  year  \
# 100  20121115X43423    HUGHES       369D  ERA13LA057  2012
#
#                     date     city state country  total_fatalities  \
# 100  11/15/2012 00:00:00  CORNING    NY     USA                 2
#
#     latimes_make latimes_model latimes_make_and_model
# 100       HUGHES           369             HUGHES 369

# %%
accident_list["city"].value_counts()
# Out:
# city
# MORRISTOWN    2
# TUCSON        2
# FLAGSTAFF     2
# PHOENIX       2
# CHEROKEE      2
#              ..
# FOSSIL        1
# BOONSBORO     1
# GEORGETOWN    1
# FRANKLIN      1
# JONESBORO     1
# Name: count, Length: 158, dtype: int64

# %%
accidents_by_city = accident_list["city"].value_counts()

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
  print(accidents_by_city)
# Out:
# city
# MORRISTOWN                  2
# TUCSON                      2
# FLAGSTAFF                   2
# PHOENIX                     2
# CHEROKEE                    2
# SHEPHERD                    1
# TALKEETNA                   1
# CROSS TIMBERS               1
# DELANO                      1
# THOMPSON FALLS              1
# ACTON                       1
# EUREKA                      1
# DAGSBORO                    1
# MANCHESTER                  1
# OKLAHOMA CITY               1
# SOMERVILLE                  1
# CLEAR LAKE                  1
# MIAMI                       1
# PADUCAH                     1
# CABALLO                     1
# VENICE, LA                  1
# INTRACOASTAL CITY           1
# ACKERLY                     1
# CORONA                      1
# BROWNSVILLE                 1
# SPOKANE                     1
# KINGFISHER                  1
# CROWLEY                     1
# COOLBAUGH TOWNSHIP          1
# BLANCO                      1
# HOUSTON                     1
# ...

# %%
merged_list
# Out:
#    latimes_make_and_model  accidents  total_hours
# 0              AGUSTA 109          2       362172
# 1              AIRBUS 130          1      1053786
# 2              AIRBUS 135          4       884596
# 3              AIRBUS 350         29      3883490
# 4                BELL 206         30      5501308
# 5                BELL 407         13      2113788
# 6              HUGHES 369         13      1201688
# 7   MCDONNELL DOUGLAS 369          6       550689
# 8            ROBINSON R22         20      2970806
# 9            ROBINSON R44         38      2359729
# 10          SCHWEIZER 269          5      1139326
# 11            SIKORSKY 76          2       915515

# %%
2 / 10
# Out:
# 0.2

# %%
merged_list["per_hour"] = merged_list["accidents"]/merged_list["total_hours"]

# %%
merged_list
# Out:
#    latimes_make_and_model  accidents  total_hours      per_hour
# 0              AGUSTA 109          2       362172  5.522238e-06
# 1              AIRBUS 130          1      1053786  9.489593e-07
# 2              AIRBUS 135          4       884596  4.521838e-06
# 3              AIRBUS 350         29      3883490  7.467510e-06
# 4                BELL 206         30      5501308  5.453249e-06
# 5                BELL 407         13      2113788  6.150096e-06
# 6              HUGHES 369         13      1201688  1.081812e-05
# 7   MCDONNELL DOUGLAS 369          6       550689  1.089544e-05
# 8            ROBINSON R22         20      2970806  6.732180e-06
# 9            ROBINSON R44         38      2359729  1.610354e-05
# 10          SCHWEIZER 269          5      1139326  4.388560e-06
# 11            SIKORSKY 76          2       915515  2.184563e-06

# %%
merged_list["per_100k_hours"] = merged_list["per_hour"] *100000

# %%
ranked_list = merged_list.sort_values("per_100k_hours", ascending=False)

# %%
ranked_list
# Out:
#    latimes_make_and_model  accidents  total_hours      per_hour  \
# 9            ROBINSON R44         38      2359729  1.610354e-05
# 7   MCDONNELL DOUGLAS 369          6       550689  1.089544e-05
# 6              HUGHES 369         13      1201688  1.081812e-05
# 3              AIRBUS 350         29      3883490  7.467510e-06
# 8            ROBINSON R22         20      2970806  6.732180e-06
# 5                BELL 407         13      2113788  6.150096e-06
# 0              AGUSTA 109          2       362172  5.522238e-06
# 4                BELL 206         30      5501308  5.453249e-06
# 2              AIRBUS 135          4       884596  4.521838e-06
# 10          SCHWEIZER 269          5      1139326  4.388560e-06
# 11            SIKORSKY 76          2       915515  2.184563e-06
# 1              AIRBUS 130          1      1053786  9.489593e-07
#
#     per_100k_hours
# 9         1.610354
# 7         1.089544
# 6         1.081812
# 3         0.746751
# 8         0.673218
# ...

# %%
ranked_list.to_csv("accident-rate-ranking.csv", index=False)
